# %% [markdown]
# # Procesos estocásticos

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

#definimos constantes
omega = 2*np.pi*0.1 #rad/seg
n = np.arange(0,128) #eje de tiempos

A = np.random.randint(1,7,(10,1))

x = A * np.sin(omega*n)

plt.plot(x.T)
# Out:
# <img src="data:image/png;base64,..." width="961">
# [<matplotlib.lines.Line2D at 0x7efd3cb13c50>,
#  <matplotlib.lines.Line2D at 0x7efd3cb13da0>,
#  <matplotlib.lines.Line2D at 0x7efd3cb13ef0>,
#  <matplotlib.lines.Line2D at 0x7efd3cb1d080>,
#  <matplotlib.lines.Line2D at 0x7efd3cb1d1d0>,
#  <matplotlib.lines.Line2D at 0x7efd3cb1d320>,
#  <matplotlib.lines.Line2D at 0x7efd3cb1d470>,
#  <matplotlib.lines.Line2D at 0x7efd3cb1d5c0>,
#  <matplotlib.lines.Line2D at 0x7efd3cb1d710>,
#  <matplotlib.lines.Line2D at 0x7efd3cb1d860>]
